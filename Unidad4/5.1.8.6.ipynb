# %% [markdown]
# # Violeta Rodriguez Avitia
# ## Estructura y Organizacion de datos
# ### Ejemplo 5.1.8.6

# %%
#Insentardo a travez de cadenas 
exampleString = 'silly walks'

for ix in range(len(exampleString)):
    print(exampleString[ix], end=' ')

print()
# Out:
# s i l l y   w a l k s
